# %%
import pandas as pd

# %%
df = pd.read_csv('cases_data.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115 entries, 0 to 114
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Case Number     115 non-null    object
#  1   Parties         115 non-null    object
#  2   Date Delivered  115 non-null    object
#  3   Court           109 non-null    object
#  4   Case Action     115 non-null    object
#  5   Judge(s)        115 non-null    object
#  6   Citation        114 non-null    object
#  7   County          115 non-null    object
#  8   Full Text       115 non-null    object
# dtypes: object(9)
# memory usage: 8.2+ KB

# %%
df.head(10)
# Out:
#                                          Case Number  \
# 0                                   Cause 28 of 2020
# 1     Tribunal Case 308 & 309 of 2020 (Consolidated)
# 2                            Civil Case E001 of 2024
# 3                         Tribunal Case E592 of 2024
# 4                         Tribunal Case E742 of 2021
# 5                         Tribunal Case E123 of 2024
# 6                         Tribunal Case E551 of 2023
# 7  Employment and Labour Relations Cause 331 of 2014
# 8             Miscellaneous Application E011 of 2022
# 9                         Tribunal Case E079 of 2024
#
#                                              Parties Date Delivered  \
# 0                      Chelagat v Kabarak University    04 Jul 2024
# 1  Alwy & another v Engroup (K) International Lim...    27 Aug 2024
# 2                                      Ajiba v Manya    05 Sep 2024
# 3                Sharif v Munyoki t/a Kauma Hardware    29 Aug 2024
# ...

# %%
df.tail(10)
# Out:
#                         Case Number                                  Parties  \
# 105  Criminal Revision E007 of 2024                        Ndungu v Republic
# 106         Criminal Case 2 of 2018                      Republic v Ng'ang'a
# 107      Criminal Case E023 of 2024           Kinuthia & 6 others v Republic
# 108              Cause E172 of 2023    Miano v Kenya Institute of Management
# 109              Cause 1514 of 2018      Njanjo v Jomat Construction Limited
# 110    Succession Cause 543 of 2002  In re Estate of Joshua Munyi (Deceased)
# 111      Criminal Appeal 18 of 2018                      Abdallah v Republic
# 112     Criminal Appeal 196 of 2017                       Kifunyi v Republic
# 113  Civil Application E220 of 2022        Sustainet Group Limited v Wanguhu
# 114    Succession Cause 104 of 2017  In re Estate of Jonah Thumbi (Deceased)
#
#     Date Delivered                                             Court  \
# ...
